# %% [markdown]
# Загрузка датасетов из внешних источников

# %%
import pandas as pd
import os

# %%
splits = {'train': 'train.csv', 'validation': 'validation.csv', 'test': 'test.csv'}
load_path = "hf://datasets/aai510-group1/telco-customer-churn/"
root_dir = os.getcwd()

save_path = os.path.join(root_dir, 'data', 'raw')
os.makedirs(save_path, exist_ok=True)
name_file = 'raw_eda_telco_customer_churn_'

for key in splits.keys():
    df = pd.read_csv(load_path + splits[key])
    f = name_file + key + '.csv'
    print(f)
    df.to_csv(os.path.join(save_path, f), index=False)
# Out:
# raw_eda_telco_customer_churn_train.csv
# raw_eda_telco_customer_churn_validation.csv
# raw_eda_telco_customer_churn_test.csv

# %%
print(save_path)
# Out:
# /home/vvk/python/Auto_ML/telco_project/notebooks/data/raw
